# %% [markdown]
# # Programs on Conditional Statements (IV)

# %% [markdown]
# ## Exercise 1
#
# Given three distinct integers A, B and C. Find out the smallest of them.
# **Sample I/O**
#
# ***Input1:***
# -14 -1 17
# ***Output1:***
# -14
#
# ***Input2:***
# 2 1 3
# ***Output2:***
# 1
#
# ***Input3:***
# 1324 1243 1234
# ***Output3:***
# 1234
#
# ***Input4:***
# -11 -16 -19
# ***Output4:***
# -19

# %%
# Write your code here

# %% [markdown]
# ## Exercise 2
#
# ***GRADE THE STUDENT***
# You are given the marks (out of 100) a student scored in 5 different subjects viz. English, Maths, Physics, Chemistry and Computer Science. Grade the student based on his/her **PERCENTAGE**.
#
# **Grading Criteria**
#
#
#
#
# - It is guaranteed that the marks entered for each subject is $\leq$100
# - Adjust the percentage to 2 decimal values after point
#
# **Sample I/O**
#
# ***Input1:***
# 35 35 35 35 35
# ***Output1:***
# Total Marks: 175
# Percentage: 35.00
# Grade: E
#
# ***Input2:***
# 90 90 90 90 90
# ***Output2:***
# Total Marks: 450
# Percentage: 90.00
# Grade: O
#
# ***Input3:***
# 45 90 55 65 60
# ***Output3:***
# Total Marks: 315
# Percentage: 63.00
# Grade: C
#
# ***Input4:***
# 75 85 80 55 65
# ***Output4:***
# Total Marks: 360
# Percentage: 72.00
# Grade: B
#
# ***Input5:***
# 35 25 20 37 27
# ***Output5:***
# Total Marks: 144
# Percentage: 28.80
# Grade: F

# %%
# Write your code here

# %% [markdown]
# ## Exercise 3
#
# Rolex bought a watch for X rupees and sold it for Y rupees. Determine the result of this transaction.
#
# Further if Rolex suffered **Loss** during the transaction calculate and print the following
# - Loss Amount
# - Loss Percentage
#
# Just like that calculate and print
# - Profit Amount
# - Profit Percentage
#
# if Rolex got **Profit** during the transaction.
#
# - Adjust the Profit/Loss Percentage to **4 decimal values** after point
#
# **Note:** It's possible that Rolex get neither profit nor loss in some scenarios. In those scenarios print *No Profit No Loss*
#
# **Sample I/O**
#
# ***Input1:***
# 100 90
# ***Output1:***
# Loss
# Loss Amount: 10
# Loss Percentage: 10.0000
#
# ***Input2:***
# 100 135
# ***Output2:***
# Profit
# Profit Amount: 35
# Profit Percentage: 35.0000
#
# ***Input3:***
# 156 247
# ***Output3:***
# Profit
# Profit Amount: 91
# Profit Percentage:  58.3333
#
# ***Input4:***
# 1234 1234
# ***Output4:***
# No Profit No Loss

# %%
# Write your code here

# %% [markdown]
# ## Exercise 4
#
# Hermoine has three spells. Their powers are A, B, and C respectively. Initially, Hermoine has 0 hit points, and if she uses a spell with power P, then her number of hit points increases by P.
#
# Before going to sleep, Hermoine wants to use exactly two spells out of these three. Find the maximum number of hit points Hermoine can have after using the spells.
#
# **Sample I/O**
#
# ***Input1:***
# 10 14 18
# ***Output1:***
# 32
#
# ***Input2:***
# 16 18 47
# ***Output2:***
# 65
#
# ***Input3:***
# 6 7 3
# ***Output3:***
# 13
#
# ***Input4:***
# 120 119 121
# ***Output4:***
# 241

# %%
# Write your code here

# %% [markdown]
# ## Exercise 5
#
# Tokyo and Rio are playing a game with a number X. In one turn, they can multiply X with 2. The goal of the game is to make X divisible by 10.
#
# Help the Tokyo and Rio find the smallest number of turns necessary to win the game (it may be possible to win in zero turns) or determine that it is impossible (in which case -1 is the answer).
#
# **Sample I/O**
#
# ***Input1:***
# 120
# ***Output1:***
# 0
#
# ***Input2:***
# 625
# ***Output2:***
# 1
#
# ***Input3:***
# 1<br>
# ***Output3:***
# -1
#
# ***Input4:***
# 3<br>
# ***Output4:***
# -1

# %%
# Write your code here

# %% [markdown]
# ## Exercise 6
#
# Alice has a bucket of water initially having W litres of water in it. The maximum capacity of the bucket is X liters.
#
# Alice turned on the tap and the water starts flowing into the bucket at a rate of Y litres/hour. She left the tap running for exactly Z hours. Determine whether the bucket has been overflown, filled exactly, or is still left unfilled.
#
# **Sample I/O**
#
# ***Input1:***
# 1 2 3 4
# ***Output1:***
# overflow
#
# ***Input2:***
# 10 70 10 6
# ***Output2:***
# filled
#
# ***Input3:***
# 2 100 4 3
# ***Output3:***
# unfilled
#
# ***Input4:***
# 2 3 2 1
# ***Output4:***
# overflow

# %%
# Write your code here

# %% [markdown]
# ## Exercise 7
#
# Mario transforms each time he eats a mushroom as follows:
#
# - If he is currently small, he turns normal.
# - If he is currently normal, he turns huge.
# - If he is currently huge, he turns small.
#
# Given that **Mario was initially normal**, find his size after eating X mushrooms.
#
# **Sample I/O**
#
# ***Input1:***
# 2<br>
# ***Output1:***
# SMALL
#
# ***Input2:***
# 4<br>
# ***Output2:***
# HUGE
#
# ***Input3:***
# 12
# ***Output3:***
# NORMAL
#
# ***Input4:***
# 17
# ***Output4:***
# SMALL

# %%
# Write your code here

# %% [markdown]
# ## Exercise 8
#
# Kaprekar calls a number X Lucky, if and only if it is divisible by **exactly** two of the given three integers A, B and C.
#
# Given X, A, B and C, help Kaprekar determine if X is Lucky or Not.
#
# If X is Lucky
# - Print Lucky
# - And also print the 2 numbers that divide X
#
# Ohterwise
# - Print Unlucky
#
#
# **Sample I/O**
#
# ***Input1:***
# 12 3 4 6
# ***Output1:***
# UNLUCKY
#
# ***Input2:***
# 16 8 7 4
# ***Output2:***
# LUCKY
# 8 4
#
# ***Input3:***
# 51 3 17 20
# ***Output3:***
# LUCKY
# 3 17
#
# ***Input4:***
# 64 3 4 5
# ***Output4:***
# UNLUCKY
#
# ***Input5:***
# 120 61 20 40
# ***Output5:***
# LUCKY
# 20 40

# %%
# Write your code here

# %% [markdown]
# ## Exercise 9
#
# ***Electricty Bill***
#
# You have to calculate the monthly Electricity Bill of a customer based on No. of Units U consumed.
#
# Rupees per unit vary depending upon the unit consumption.
#
# Here is the detailed cost_per_unit for different unit consumptions.
#
# |Unit consumption|Cost per Unit|
# |:--|:--|
# |Upto 199| 1.20|
# |>=200 but <400| 1.40|
# |>=400 but <600| 1.60|
# |>=600 but <800| 1.80|
# |>=800|2.00|
#
# - Also if **bill exceeds Rs. 400 a surcharge of 15% of the bill amount** should be charged.
#
# **Sample I/O**
#
# ***Input1:***
# 800
# ***Output1:***
# Units Consumed: 800
# Cost per Unit: 2.00
# Bill: 1600.00
# Surcharge: 240.00
# Total Amount: 1840.00
#
# ***Input2:***
# 250
# ***Output2:***
# Units Consumed: 250
# Cost per Unit: 1.40
# Bill: 350.00
# Surcharge: 0.00
# Total  Amount: 350.00
#
# ***Input3:***
# 500
# ***Output3:***
# Units Consumed: 500
# Cost per Unit: 1.60
# Bill: 800.00
# Surcharge: 120.00
# Total  Amount: 920.00
#
# ***Input4:***
# 100
# ***Output4:***
# Units Consumed: 100
# Cost per Unit: 1.20
# Bill: 120.00
# Surcharge: 0.00
# Total  Amount: 120.00
#
# ***Input5:***
# 650
# ***Output5:***
# Units Consumed: 650
# Cost per Unit: 1.80
# Bill: 1170.00
# Surcharge: 175.50
# Total  Amount: 1345.50

# %%
# Write your code here
